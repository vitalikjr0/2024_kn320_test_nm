# %% [markdown]
# ## Завдання на екзамен
# 1. Написати тест до програми з лаб №3 swords.py та протестувати функцію get_buff_damag
# - стврорюємо файл у папці лаб 3 де будемо писати тест, називаємо test_exam.py
# - пишемо код для реалізації нашого завдання
# - запустити код на виконання та представити результати
# - результат запуску на скріншоті ![](exam_final.jpg)
#
# 2. У роботі №1, у проекті №4 дописати додаткову веб сторінку (info) за допомогою бібліотеки Flask/модифікувати файл app.py
# - в папці lab_1/4_project знайти файл app.py та в ньому дописати функцію яка буде вивидити веб стоорінку з шляхом info;
# - після того як ми зробили функцію для завдання з екзамену, потрібно її запустити та показати як вона працює;
# - результат роботи нашої функції представлено на скріншоті ![](./exam_consult.jpg)

# %% [markdown]
# ## Завдання на Екзамен (16 квітня)

# %% [markdown]
# 1. У роботі №1, модифікувати проект 1_project, за допомогою бібліотеки requests зайти на сторінку https://itcollege.lviv.ua/ та вивести її вміст
#
# 2. (__Руслан Волохов__) У роботі №3, для файлу swords_bonus.py написати тест до методу list_bonus_methods
#
# 3. (__Євген Паньків__) У роботі №1, у проекті 2_project інсталювати бібліотеку matplotlib та виконати приклад з https://matplotlib.org/stable/users/getting_started/
#
# 4. (__Володимир Максимів__) У роботі №2, для файлу game/sword.py протестувати функцію bonus_invincible з класу SwordBonus (написати юніт тест)
#
# 5. (__Максим Кузів__) У роботі №2, для файлу game/sword.py створити новий бонус меча у класу SwordBonus який буде збільшувати damage на 5
#
# 6. (__Олег Любас__) У роботі №1, у проекті 3_project, задати змінну середовища під назвою EXAM та вивести її при виконання програми 3.py
#
# 7. (__Олександр Сорока__) У роботі №2, для файлу game/sword.py модифікувати метод bonus_poison щоб отрута тепер наносила шкоду мечу і забирала 2 vitality
#
# 8. (__Володимир Цар__) У роботі №3, встановити у віртуальне середовище Pipenv бібліотеку requests та у файлі axe.py написати метод який буде заходити на сайт https://itcollege.lviv.ua/
#
# 9. (__Володимир Фученко__) У роботі №2, для файлу game/sword.py протестувати функцію get_buff_damag з класу Swords (написати юніт тест)
#
# 10. (__Максим Лук'янов__) У роботі №1, у проекті 4_project, встановити у віртуальне середовище Pipenv бібліотеку requests та викликати метод requests.get коли викликається головна сторінка index з файлу app.py
#
# 11. У роботі №3, у файлі test.py модифікувати тест test_create_sword_from_random_rarity з класу TestSwordsCreation щоб створювалось декілька мечів у циклі та перевірялась їх рідкісність
#
# 12. (__Роман Баврук__) У роботі №2, для файлу game/sword.py протестувати функцію bonus_berserk з класу SwordBonus (написати юніт тест)
#
# 13. (__Остап Сидоренко__) У роботі №3, у файлі app.py модифікувати функцію create_players та зробіть перевірку щоб Імя гравця складалось хочаб з декількох букв
#
# 14. У роботі №2, для файлу game/sword.py модифікувати конструктор класу Swords та задати значення імені меча name по замовчуванню як Простий Меч
#
# 15. (__Юрій Томаневич__) У роботі №3, у файлі axe.py створіть метод стрічкового представлення обєкту (при застосування функції print до обєкту) та який буде повертати стрічку де буде розкриватись атрибут name
#
# 16. (__Богдан Теодоровський__) У роботі №3, у файлі test.py модифікувати тест test_player_select_buffs та зробити перевірку якщо гравець введе цифру 3 або 4
#
# 17. У роботі №2, для файлу game/sword.py дописати property для класу Swords яка буде виводити назву рідкісності меча та його поточний коефіцієн з класової змінної rarity_map
#
# 18. У роботі №1, у проекті 4_project, додати у файлі .env змінну середовища HELP та прочитати її коли заходите на веб сторінку /help
#
# 19. У роботі №3, у файлі test.py модифікувати тест test_sword_with_random_rarity та дописати перевірку що рідкісність меча не може бути рівною None
#
# 20.

# %% [markdown]
# ## Здача екзамену, 16 квітня 2024р.

# %% [markdown]
# "+" Здані роботи
# "*" повідомили
# "^" прийшов на екзамен
#
# |№|Студент|Примітка|Оцінка|
# |---|---|---|---|
# |1. | Роман Баврук|^+|
# |2. | Руслан Волохов|^+       %|
# |3. | Максим Кузів|^+  |
# |4. | Олександр Кулак|
# |5. | Максим Лук'янов|^+|
# |6. | Олег Любас|^+|
# |7. | Володимир Максимів|^+|
# |8. | Денис Мечержак|
# |9. | Андрій Наливайко|
# |10.| Євген Паньків|^+|
# |11.| Віталій Рудницький|
# |12.| Остап Сидоренко|^+||
# |13.| Олександр Сорока|^+|
# |14.| Богдан Теодоровський|^+|
# |15.| Юрій Томаневич|^+||
# |16.| Роман Фостик|
# |17.| Володимир Фученко|^+|
# |18.| Володимир Цар|^+|
# |19.| Назар Якимяк|
